# %%
import numpy as np
import matplotlib.pyplot as plt

from Player import player_main
from Helper_functions import get_pattern,generate_image,tester
# from tictactoe.tictactoe import terminal

# %%
querry = get_pattern(None)
img = generate_image(querry)

# %%
plt.imshow(img)

# %%
user = "X"

# %%
print(tester(querry, user))
# Out:
# None

# %%
while tester(querry, user) is None:
    img = generate_image(querry)
    plt.imshow(img)
    plt.show()
    querry = player_main(querry, user)[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 6
#       4 plt.imshow(img)
#       5 plt.show()
# ----> 6 querry = player_main(querry, user)[0]
#
# File ~/Desktop/Code/Git Files/tic-tac-toe_player-agent/Player.py:80, in player_main(Array, user)
#      78     return Array, acts
#      79 else:
# ---> 80     mov = int(input("Enter the move: "))
#      81     move = (mov//3, mov%3)
#      83     if move not in acts:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
if tester(querry, user) == 1:
    print("You won!")
elif tester(querry, user) == -1:
    print("You lost!")

# %%
querry = player_main(querry, user)[0]

# %%
querry

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
querry = player_main(querry, user)[0]  # move is from 0 - 9 in the grid

# %%
querry

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
tester(querry, user)
