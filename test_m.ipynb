# %%
import numpy as np
import matplotlib.pyplot as plt

from Player import player_main
from Helper_functions import get_pattern,generate_image,tester

# %%
from main import player_agent

# %%
player_agent()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/divyansh/Divyansh-Work/ICG-Works/Logistics/tic-tac-toe_player-agent/test_m.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/home/divyansh/Divyansh-Work/ICG-Works/Logistics/tic-tac-toe_player-agent/test_m.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> player_agent()
#
# File ~/Divyansh-Work/ICG-Works/Logistics/tic-tac-toe_player-agent/main.py:41, in player_agent()
#      34 img = generate_image(querry)
#      38 """
#      39 user_response = player(pattern_img)
#      40 """
# ---> 41 response = player_main(img)
#      44 """
#      45 result = tester(querry_array, user)
#      46 """
#      47 result = tester(response,querry)
#
# TypeError: player_main() missing 1 required positional argument: 'user'

# %%
querry = get_pattern([2, 2, 2, 0, 2,  2, 2, 2, 2])
img = generate_image(querry)

# %%
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %%
user = "X"

# %%
querry = player_main(querry, user)[0]

# %%
querry
# Out:
# [2, 2, 2, 0, 2, 1, 2, 2, 2]

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
querry = player_main(querry, user)[0]  # move is from 0 - 9 in the grid
# Out:
# Invalid move

# %%
querry
# Out:
# [0, 2, 2, 0, 2, 1, 2, 2, 2]

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
tester(querry, user)
# Out:
# -1
