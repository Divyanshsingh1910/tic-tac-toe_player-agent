# %%
import numpy as np
import matplotlib.pyplot as plt

from Player import player_main
from Helper_functions import get_pattern,generate_image,tester

# %%
querry = get_pattern([2, 2, 2, 0, 2,  2, 2, 2, 2])
img = generate_image(querry)

# %%
plt.imshow(img)

# %%
user = "X"

# %%
player_main([0, 1, 2, 0, 1, 2, 1, 2, 2], 'X')
# Out:
# (None, None)

# %%
player_main([2, 2, 2, 2, 0, 2, 2, 2, 2], user)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 player_main([2, 2, 2, 2, 0, 2, 2, 2, 2], user)
#
# File ~/Desktop/Code/Git Files/tic-tac-toe_player-agent/Player.py:104, in player_main(Array, user)
#      87             return None, None
#      89 # for act in acts:
#      90 #     copy = char_array.copy()
#      91 #     copy = result(copy,act)
#    (...)
#     102 # random_action = random.choice(list(acts))
#     103 # return random_action , turn
# --> 104 turn = player(board)
#     105 #other option is to play the optimum action
#     106 opt = minimax(char_array)
#
# File ~/Desktop/Code/Git Files/tic-tac-toe_player-agent/tictactoe/tictactoe.py:31, in player(board)
#      29 for row in range(3):
#      30     for col in range(3):
# ---> 31         if board[row][col] == X:
#      32             countX += 1
#      33         elif board[row][col] == O:
#
# IndexError: invalid index to scalar variable.

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
tester(querry, user)
