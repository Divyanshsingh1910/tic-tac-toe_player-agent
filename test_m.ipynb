# %%
import numpy as np
import matplotlib.pyplot as plt

from Player import player_main, turn
from tictactoe.tictactoe import terminal
from Helper_functions import get_pattern,generate_image,tester
# from tictactoe.tictactoe import terminal

# %%
querry = get_pattern([2,1,0,2,1,0,2,2,0])
img = generate_image(querry)

# %%
plt.imshow(img)

# %%
user = turn(querry)

# %%
print(tester(querry, user))
# Out:
# 1

# %%
while tester(querry, user) is None:
    img = generate_image(querry)
    plt.imshow(img)
    plt.show()
    querry = player_main(querry, user)[0]

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
if tester(querry, user) == 1:
    print("You won!")
elif tester(querry, user) == -1:
    print("You lost!")
else:
    print("It's a draw!")

# %%
querry = player_main(querry, user)[0]

# %%
querry

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
querry = player_main(querry, user)[0]  # move is from 0 - 9 in the grid

# %%
querry

# %%
img = generate_image(querry)
plt.imshow(img)

# %%
tester(querry, user)

# %%
#  git pull 
def functoret_image(arr):
    gen_image = [0,1]

    return gen_image

# %% [markdown]
# git add test_m.ipynb
#
# git add .
