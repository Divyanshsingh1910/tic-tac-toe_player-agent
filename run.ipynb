# %%
from main_m import player_agent
from Helper_functions import get_pattern

# %%
# load querry from the test database
querry = get_pattern(None)

# %%
player_agent(querry)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 player_agent(querry)
#
# File ~/Desktop/Code/Git Files/tic-tac-toe_player-agent/main_m.py:27, in player_agent(arr)
#      25 while tester(arr, user) is None:
#      26     arr = player_main(arr, user)[0]
# ---> 27     img = generate_image(arr)
#      28     plt.imshow(img)
#      29     plt.show()
#
# File ~/Desktop/Code/Git Files/tic-tac-toe_player-agent/Helper_functions.py:95, in generate_image(Array)
#      90 small_matrix = []
#      92 for i in range(m):
#      93
#      94         # 1 for cross
# ---> 95         if Array[i] == 1:
#      96             x = choose_image_1()
#      97             x_np = png_to_array(x)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
